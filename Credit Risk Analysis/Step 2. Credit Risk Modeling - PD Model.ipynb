# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col = 0)

# %% [markdown]
# ### Explore Data

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86
# 427211                            0                           0
# 206088                            0                           0
# 136020                            0                           0
# 412305                            0                           0
# 36159                             0                           0
#
# [5 rows x 314 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 314)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 314)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %% [markdown]
# ### Selecting the Features

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 104 columns]

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-0.42331201])

# %%
reg.coef_
# Out:
# array([[ 0.95661301,  0.75097701,  0.56972441,  0.38891223,  0.23414829,
#          0.06019956,  0.09107233,  0.10357338,  0.04316737,  0.06959456,
#          0.0663156 ,  0.0705994 ,  0.08725677,  0.14685286,  0.11382941,
#          0.19630467,  0.24234602,  0.23418572,  0.27480927,  0.33596615,
#          0.49189205,  0.08288705, -0.01565145,  0.27378904,  0.17163237,
#          0.17781097,  0.2315079 ,  0.05134325,  0.07191667,  0.10953448,
#          0.13427551,  0.10208314,  0.06871146,  0.12917567,  1.12614334,
#          0.93436006,  0.83601067,  0.64101598,  0.48044423,  0.235619  ,
#         -0.01599717,  0.97470617,  0.62429586,  0.36109087,  0.15109467,
#          0.07660743,  0.05822424,  0.10462854,  0.1417057 ,  0.14762215,
#         -0.03517891, -0.06261865,  0.28779861,  0.14551345, -0.06341245,
#          0.07111582, -0.03928697, -0.06285538, -0.08920642, -0.07380393,
#         -0.04993862, -0.10534915,  0.13119273,  0.08966502, -0.02132435,
#          0.03170864,  0.16152847,  0.04383066,  0.00943958,  0.00386176,
#          0.02073202,  0.03555059,  0.06178714,  0.20254909, -0.18296998,
#         -0.11262535, -0.01430881,  0.05367295,  0.13174384,  0.20503524,
#          0.27763995,  0.29286136,  0.37230553,  0.48964209,  0.39817029,
#          0.05233996,  0.17354741,  0.20004441,  0.14144942,  0.06127575,
#         -0.03655839, -0.04802498, -0.08298127, -0.11969734,  0.07699256,
#          0.12433892,  0.15248609,  0.10442526,  0.11710664,  0.20345423,
#          0.12703853,  0.29615957, -0.0619966 ,  0.02318668]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -0.423312
# 1                                grade:A      0.956613
# 2                                grade:B      0.750977
# 3                                grade:C      0.569724
# 4                                grade:D      0.388912
# 5                                grade:E      0.234148
# 6                                grade:F      0.060200
# 7                     home_ownership:OWN      0.091072
# 8                home_ownership:MORTGAGE      0.103573
# 9                       addr_state:NM_VA      0.043167
# 10                         addr_state:NY      0.069595
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.066316
# 12                         addr_state:CA      0.070599
# 13                addr_state:UT_KY_AZ_NJ      0.087257
# 14             addr_state:AR_MI_PA_OH_MN      0.146853
# 15             addr_state:RI_MA_DE_SD_IN      0.113829
# 16                   addr_state:GA_WA_OR      0.196305
# 17                      addr_state:WI_MT      0.242346
# 18                         addr_state:TX      0.234186
# 19                      addr_state:IL_CT      0.274809
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.335966
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.491892
# 22      verification_status:Not Verified      0.082887
# 23   verification_status:Source Verified     -0.015651
# 24                   purpose:credit_card      0.273789
# 25            purpose:debt_consolidation      0.171632
# 26            purpose:oth__med__vacation      0.177811
# 27   purpose:major_purch__car__home_impr      0.231508
# 28                 initial_list_status:w      0.051343
# 29                               term:36      0.071917
# 30                          emp_length:1      0.109534
# 31                        emp_length:2-4      0.134276
# 32                        emp_length:5-6      0.102083
# 33                        emp_length:7-9      0.068711
# 34                         emp_length:10      0.129176
# 35                mths_since_issue_d:<38      1.126143
# 36              mths_since_issue_d:38-39      0.934360
# 37              mths_since_issue_d:40-41      0.836011
# 38              mths_since_issue_d:42-48      0.641016
# 39              mths_since_issue_d:49-52      0.480444
# 40              mths_since_issue_d:53-64      0.235619
# 41              mths_since_issue_d:65-84     -0.015997
# 42                       int_rate:<9.548      0.974706
# 43                 int_rate:9.548-12.025      0.624296
# 44                 int_rate:12.025-15.74      0.361091
# 45                 int_rate:15.74-20.281      0.151095
# 46   mths_since_earliest_cr_line:141-164      0.076607
# 47   mths_since_earliest_cr_line:165-247      0.058224
# 48   mths_since_earliest_cr_line:248-270      0.104629
# 49   mths_since_earliest_cr_line:271-352      0.141706
# 50      mths_since_earliest_cr_line:>352      0.147622
# 51                         delinq_2yrs:0     -0.035179
# 52                       delinq_2yrs:1-3     -0.062619
# 53                      inq_last_6mths:0      0.287799
# 54                    inq_last_6mths:1-2      0.145513
# 55                    inq_last_6mths:3-6     -0.063412
# 56                          open_acc:1-3      0.071116
# 57                         open_acc:4-12     -0.039287
# 58                        open_acc:13-17     -0.062855
# 59                        open_acc:18-22     -0.089206
# 60                        open_acc:23-25     -0.073804
# 61                        open_acc:26-30     -0.049939
# 62                         open_acc:>=31     -0.105349
# 63                           pub_rec:3-4      0.131193
# 64                           pub_rec:>=5      0.089665
# 65                       total_acc:28-51     -0.021324
# 66                        total_acc:>=52      0.031709
# 67                    acc_now_delinq:>=1      0.161528
# 68               total_rev_hi_lim:5K-10K      0.043831
# 69              total_rev_hi_lim:10K-20K      0.009440
# 70              total_rev_hi_lim:20K-30K      0.003862
# 71              total_rev_hi_lim:30K-40K      0.020732
# 72              total_rev_hi_lim:40K-55K      0.035551
# 73              total_rev_hi_lim:55K-95K      0.061787
# 74                 total_rev_hi_lim:>95K      0.202549
# 75                    annual_inc:20K-30K     -0.182970
# 76                    annual_inc:30K-40K     -0.112625
# 77                    annual_inc:40K-50K     -0.014309
# 78                    annual_inc:50K-60K      0.053673
# 79                    annual_inc:60K-70K      0.131744
# 80                    annual_inc:70K-80K      0.205035
# 81                    annual_inc:80K-90K      0.277640
# 82                   annual_inc:90K-100K      0.292861
# 83                  annual_inc:100K-120K      0.372306
# 84                  annual_inc:120K-140K      0.489642
# 85                      annual_inc:>140K      0.398170
# 86                             dti:<=1.4      0.052340
# 87                           dti:1.4-3.5      0.173547
# 88                           dti:3.5-7.7      0.200044
# 89                          dti:7.7-10.5      0.141449
# 90                         dti:10.5-16.1      0.061276
# 91                         dti:16.1-20.3     -0.036558
# 92                         dti:20.3-21.7     -0.048025
# 93                         dti:21.7-22.4     -0.082981
# 94                           dti:22.4-35     -0.119697
# 95        mths_since_last_delinq:Missing      0.076993
# 96           mths_since_last_delinq:4-30      0.124339
# 97          mths_since_last_delinq:31-56      0.152486
# 98           mths_since_last_delinq:>=57      0.104425
# 99        mths_since_last_record:Missing      0.117107
# 100          mths_since_last_record:3-20      0.203454
# 101         mths_since_last_record:21-31      0.127039
# 102         mths_since_last_record:32-80      0.296160
# 103         mths_since_last_record:81-86     -0.061997
# 104          mths_since_last_record:>=86      0.023187

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -0.423312
# 1                                grade:A      0.956613
# 2                                grade:B      0.750977
# 3                                grade:C      0.569724
# 4                                grade:D      0.388912
# 5                                grade:E      0.234148
# 6                                grade:F      0.060200
# 7                     home_ownership:OWN      0.091072
# 8                home_ownership:MORTGAGE      0.103573
# 9                       addr_state:NM_VA      0.043167
# 10                         addr_state:NY      0.069595
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.066316
# 12                         addr_state:CA      0.070599
# 13                addr_state:UT_KY_AZ_NJ      0.087257
# 14             addr_state:AR_MI_PA_OH_MN      0.146853
# 15             addr_state:RI_MA_DE_SD_IN      0.113829
# 16                   addr_state:GA_WA_OR      0.196305
# 17                      addr_state:WI_MT      0.242346
# 18                         addr_state:TX      0.234186
# 19                      addr_state:IL_CT      0.274809
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.335966
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.491892
# 22      verification_status:Not Verified      0.082887
# 23   verification_status:Source Verified     -0.015651
# 24                   purpose:credit_card      0.273789
# 25            purpose:debt_consolidation      0.171632
# 26            purpose:oth__med__vacation      0.177811
# 27   purpose:major_purch__car__home_impr      0.231508
# 28                 initial_list_status:w      0.051343
# 29                               term:36      0.071917
# 30                          emp_length:1      0.109534
# 31                        emp_length:2-4      0.134276
# 32                        emp_length:5-6      0.102083
# 33                        emp_length:7-9      0.068711
# 34                         emp_length:10      0.129176
# 35                mths_since_issue_d:<38      1.126143
# 36              mths_since_issue_d:38-39      0.934360
# 37              mths_since_issue_d:40-41      0.836011
# 38              mths_since_issue_d:42-48      0.641016
# 39              mths_since_issue_d:49-52      0.480444
# 40              mths_since_issue_d:53-64      0.235619
# 41              mths_since_issue_d:65-84     -0.015997
# 42                       int_rate:<9.548      0.974706
# 43                 int_rate:9.548-12.025      0.624296
# 44                 int_rate:12.025-15.74      0.361091
# 45                 int_rate:15.74-20.281      0.151095
# 46   mths_since_earliest_cr_line:141-164      0.076607
# 47   mths_since_earliest_cr_line:165-247      0.058224
# 48   mths_since_earliest_cr_line:248-270      0.104629
# 49   mths_since_earliest_cr_line:271-352      0.141706
# 50      mths_since_earliest_cr_line:>352      0.147622
# 51                         delinq_2yrs:0     -0.035179
# 52                       delinq_2yrs:1-3     -0.062619
# 53                      inq_last_6mths:0      0.287799
# 54                    inq_last_6mths:1-2      0.145513
# 55                    inq_last_6mths:3-6     -0.063412
# 56                          open_acc:1-3      0.071116
# 57                         open_acc:4-12     -0.039287
# 58                        open_acc:13-17     -0.062855
# 59                        open_acc:18-22     -0.089206
# 60                        open_acc:23-25     -0.073804
# 61                        open_acc:26-30     -0.049939
# 62                         open_acc:>=31     -0.105349
# 63                           pub_rec:3-4      0.131193
# 64                           pub_rec:>=5      0.089665
# 65                       total_acc:28-51     -0.021324
# 66                        total_acc:>=52      0.031709
# 67                    acc_now_delinq:>=1      0.161528
# 68               total_rev_hi_lim:5K-10K      0.043831
# 69              total_rev_hi_lim:10K-20K      0.009440
# 70              total_rev_hi_lim:20K-30K      0.003862
# 71              total_rev_hi_lim:30K-40K      0.020732
# 72              total_rev_hi_lim:40K-55K      0.035551
# 73              total_rev_hi_lim:55K-95K      0.061787
# 74                 total_rev_hi_lim:>95K      0.202549
# 75                    annual_inc:20K-30K     -0.182970
# 76                    annual_inc:30K-40K     -0.112625
# 77                    annual_inc:40K-50K     -0.014309
# 78                    annual_inc:50K-60K      0.053673
# 79                    annual_inc:60K-70K      0.131744
# 80                    annual_inc:70K-80K      0.205035
# 81                    annual_inc:80K-90K      0.277640
# 82                   annual_inc:90K-100K      0.292861
# 83                  annual_inc:100K-120K      0.372306
# 84                  annual_inc:120K-140K      0.489642
# 85                      annual_inc:>140K      0.398170
# 86                             dti:<=1.4      0.052340
# 87                           dti:1.4-3.5      0.173547
# 88                           dti:3.5-7.7      0.200044
# 89                          dti:7.7-10.5      0.141449
# 90                         dti:10.5-16.1      0.061276
# 91                         dti:16.1-20.3     -0.036558
# 92                         dti:20.3-21.7     -0.048025
# 93                         dti:21.7-22.4     -0.082981
# 94                           dti:22.4-35     -0.119697
# 95        mths_since_last_delinq:Missing      0.076993
# 96           mths_since_last_delinq:4-30      0.124339
# 97          mths_since_last_delinq:31-56      0.152486
# 98           mths_since_last_delinq:>=57      0.104425
# 99        mths_since_last_record:Missing      0.117107
# 100          mths_since_last_record:3-20      0.203454
# 101         mths_since_last_record:21-31      0.127039
# 102         mths_since_last_record:32-80      0.296160
# 103         mths_since_last_record:81-86     -0.061997
# 104          mths_since_last_record:>=86      0.023187

# %%
p_values = reg.p_values

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = p_values

# %%
summary_table[:5]
# Out:
#   Feature name  Coefficients      p_values
# 0    Intercept     -0.423312           NaN
# 1      grade:A      0.956613  1.498113e-25
# 2      grade:B      0.750977  4.815936e-34
# 3      grade:C      0.569724  2.995418e-23
# 4      grade:D      0.388912  1.003991e-12

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 84 columns]

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -0.445985
# 1                               grade:A      0.944051
# 2                               grade:B      0.732144
# 3                               grade:C      0.549044
# 4                               grade:D      0.373379
# 5                               grade:E      0.219520
# 6                               grade:F      0.049873
# 7                    home_ownership:OWN      0.096256
# 8               home_ownership:MORTGAGE      0.105095
# 9                      addr_state:NM_VA      0.044426
# 10                        addr_state:NY      0.069406
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12                        addr_state:CA      0.073258
# 13               addr_state:UT_KY_AZ_NJ      0.088412
# 14            addr_state:AR_MI_PA_OH_MN      0.145712
# 15            addr_state:RI_MA_DE_SD_IN      0.113471
# 16                  addr_state:GA_WA_OR      0.196256
# 17                     addr_state:WI_MT      0.243453
# 18                        addr_state:TX      0.232289
# 19                     addr_state:IL_CT      0.271777
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22     verification_status:Not Verified      0.080358
# 23  verification_status:Source Verified     -0.013063
# 24                  purpose:credit_card      0.283008
# 25           purpose:debt_consolidation      0.177753
# 26           purpose:oth__med__vacation      0.188407
# 27  purpose:major_purch__car__home_impr      0.242110
# 28                initial_list_status:w      0.049503
# 29                              term:36      0.080814
# 30                         emp_length:1      0.109079
# 31                       emp_length:2-4      0.133383
# 32                       emp_length:5-6      0.100128
# 33                       emp_length:7-9      0.067128
# 34                        emp_length:10      0.130179
# 35               mths_since_issue_d:<38      1.133686
# 36             mths_since_issue_d:38-39      0.944140
# 37             mths_since_issue_d:40-41      0.844111
# 38             mths_since_issue_d:42-48      0.652120
# 39             mths_since_issue_d:49-52      0.488600
# 40             mths_since_issue_d:53-64      0.243540
# 41             mths_since_issue_d:65-84     -0.007180
# 42                      int_rate:<9.548      0.964427
# 43                int_rate:9.548-12.025      0.625920
# 44                int_rate:12.025-15.74      0.361330
# 45                int_rate:15.74-20.281      0.149165
# 46  mths_since_earliest_cr_line:141-164      0.076842
# 47  mths_since_earliest_cr_line:165-247      0.057176
# 48  mths_since_earliest_cr_line:248-270      0.105623
# 49  mths_since_earliest_cr_line:271-352      0.145712
# 50     mths_since_earliest_cr_line:>352      0.152760
# 51                     inq_last_6mths:0      0.271788
# 52                   inq_last_6mths:1-2      0.127122
# 53                   inq_last_6mths:3-6     -0.080300
# 54                   acc_now_delinq:>=1      0.147718
# 55                   annual_inc:20K-30K     -0.179924
# 56                   annual_inc:30K-40K     -0.115858
# 57                   annual_inc:40K-50K     -0.021146
# 58                   annual_inc:50K-60K      0.043639
# 59                   annual_inc:60K-70K      0.121916
# 60                   annual_inc:70K-80K      0.193073
# 61                   annual_inc:80K-90K      0.269304
# 62                  annual_inc:90K-100K      0.280046
# 63                 annual_inc:100K-120K      0.360420
# 64                 annual_inc:120K-140K      0.482019
# 65                     annual_inc:>140K      0.386657
# 66                            dti:<=1.4      0.059121
# 67                          dti:1.4-3.5      0.169936
# 68                          dti:3.5-7.7      0.203104
# 69                         dti:7.7-10.5      0.136558
# 70                        dti:10.5-16.1      0.055871
# 71                        dti:16.1-20.3     -0.046006
# 72                        dti:20.3-21.7     -0.064257
# 73                        dti:21.7-22.4     -0.093388
# 74                          dti:22.4-35     -0.137457
# 75       mths_since_last_delinq:Missing      0.082870
# 76          mths_since_last_delinq:4-30      0.106341
# 77         mths_since_last_delinq:31-56      0.150261
# 78          mths_since_last_delinq:>=57      0.100756
# 79       mths_since_last_record:Missing      0.102070
# 80          mths_since_last_record:3-20      0.208104
# 81         mths_since_last_record:21-31      0.120604
# 82         mths_since_last_record:32-80      0.276375
# 83         mths_since_last_record:81-86     -0.091750
# 84          mths_since_last_record:>=86     -0.004813

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -0.445985            NaN
# 1                               grade:A      0.944051   4.229369e-25
# 2                               grade:B      0.732144   1.440979e-32
# 3                               grade:C      0.549044   7.371959e-22
# 4                               grade:D      0.373379   5.637468e-12
# 5                               grade:E      0.219520   5.131963e-06
# 6                               grade:F      0.049873   3.185217e-01
# 7                    home_ownership:OWN      0.096256   1.835873e-06
# 8               home_ownership:MORTGAGE      0.105095   9.223599e-17
# 9                      addr_state:NM_VA      0.044426   1.648468e-01
# 10                        addr_state:NY      0.069406   4.138647e-03
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066681   3.919362e-03
# 12                        addr_state:CA      0.073258   5.360600e-04
# 13               addr_state:UT_KY_AZ_NJ      0.088412   3.809330e-04
# 14            addr_state:AR_MI_PA_OH_MN      0.145712   9.345432e-11
# 15            addr_state:RI_MA_DE_SD_IN      0.113471   1.429824e-04
# 16                  addr_state:GA_WA_OR      0.196256   1.782790e-13
# 17                     addr_state:WI_MT      0.243453   2.940800e-07
# 18                        addr_state:TX      0.232289   3.588608e-19
# 19                     addr_state:IL_CT      0.271777   1.263475e-20
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.333680   2.910328e-27
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500647   1.798297e-21
# 22     verification_status:Not Verified      0.080358   3.622018e-08
# 23  verification_status:Source Verified     -0.013063   3.307871e-01
# 24                  purpose:credit_card      0.283008   2.067570e-23
# 25           purpose:debt_consolidation      0.177753   1.012215e-11
# 26           purpose:oth__med__vacation      0.188407   1.518854e-09
# 27  purpose:major_purch__car__home_impr      0.242110   1.019727e-14
# 28                initial_list_status:w      0.049503   1.495693e-04
# 29                              term:36      0.080814   7.416943e-09
# 30                         emp_length:1      0.109079   2.618237e-05
# 31                       emp_length:2-4      0.133383   1.512758e-12
# 32                       emp_length:5-6      0.100128   2.853152e-06
# 33                       emp_length:7-9      0.067128   1.235143e-03
# 34                        emp_length:10      0.130179   1.563383e-12
# 35               mths_since_issue_d:<38      1.133686  9.981814e-203
# 36             mths_since_issue_d:38-39      0.944140  1.063478e-176
# 37             mths_since_issue_d:40-41      0.844111  2.714730e-149
# 38             mths_since_issue_d:42-48      0.652120  5.534130e-115
# 39             mths_since_issue_d:49-52      0.488600   3.162987e-57
# 40             mths_since_issue_d:53-64      0.243540   2.522586e-17
# 41             mths_since_issue_d:65-84     -0.007180   8.031001e-01
# 42                      int_rate:<9.548      0.964427   1.130093e-36
# 43                int_rate:9.548-12.025      0.625920   1.240778e-44
# 44                int_rate:12.025-15.74      0.361330   7.857323e-23
# 45                int_rate:15.74-20.281      0.149165   2.752249e-07
# 46  mths_since_earliest_cr_line:141-164      0.076842   1.987924e-03
# 47  mths_since_earliest_cr_line:165-247      0.057176   4.298403e-03
# 48  mths_since_earliest_cr_line:248-270      0.105623   5.594168e-05
# 49  mths_since_earliest_cr_line:271-352      0.145712   4.603632e-10
# 50     mths_since_earliest_cr_line:>352      0.152760   7.998701e-09
# 51                     inq_last_6mths:0      0.271788   2.863685e-03
# 52                   inq_last_6mths:1-2      0.127122   1.626701e-01
# 53                   inq_last_6mths:3-6     -0.080300   3.806585e-01
# 54                   acc_now_delinq:>=1      0.147718   1.633147e-01
# 55                   annual_inc:20K-30K     -0.179924   2.989982e-05
# 56                   annual_inc:30K-40K     -0.115858   5.255335e-03
# 57                   annual_inc:40K-50K     -0.021146   6.100014e-01
# 58                   annual_inc:50K-60K      0.043639   2.983736e-01
# 59                   annual_inc:60K-70K      0.121916   4.464635e-03
# 60                   annual_inc:70K-80K      0.193073   9.913134e-06
# 61                   annual_inc:80K-90K      0.269304   3.048331e-09
# 62                  annual_inc:90K-100K      0.280046   2.403598e-09
# 63                 annual_inc:100K-120K      0.360420   9.829187e-15
# 64                 annual_inc:120K-140K      0.482019   8.655368e-20
# 65                     annual_inc:>140K      0.386657   1.435115e-15
# 66                            dti:<=1.4      0.059121   4.903890e-01
# 67                          dti:1.4-3.5      0.169936   1.960242e-02
# 68                          dti:3.5-7.7      0.203104   1.432296e-03
# 69                         dti:7.7-10.5      0.136558   3.111326e-02
# 70                        dti:10.5-16.1      0.055871   3.632459e-01
# 71                        dti:16.1-20.3     -0.046006   4.546610e-01
# 72                        dti:20.3-21.7     -0.064257   3.159130e-01
# 73                        dti:21.7-22.4     -0.093388   1.693526e-01
# 74                          dti:22.4-35     -0.137457   2.400711e-02
# 75       mths_since_last_delinq:Missing      0.082870   1.113282e-01
# 76          mths_since_last_delinq:4-30      0.106341   4.345328e-02
# 77         mths_since_last_delinq:31-56      0.150261   4.832156e-03
# 78          mths_since_last_delinq:>=57      0.100756   6.491165e-02
# 79       mths_since_last_record:Missing      0.102070   1.694579e-01
# 80          mths_since_last_record:3-20      0.208104   7.774547e-02
# 81         mths_since_last_record:21-31      0.120604   2.611570e-01
# 82         mths_since_last_record:32-80      0.276375   4.353017e-04
# 83         mths_since_last_record:81-86     -0.091750   2.842163e-01
# 84          mths_since_last_record:>=86     -0.004813   9.494028e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))

# %% [markdown]
# # PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation (test)

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 362514              0  ...                               1
# 288564              0  ...                               0
# 213591              0  ...                               0
# 263083              0  ...                               1
# 165001              0  ...                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>=86
# 362514                            0
# 288564                            0
# 213591                            0
# 263083                            0
# 165001                            0
#
# [5 rows x 84 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)

# %%
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.07576417, 0.92423583],
#        [0.14980296, 0.85019704],
#        [0.11484452, 0.88515548],
#        ...,
#        [0.02692721, 0.97307279],
#        [0.04022367, 0.95977633],
#        [0.04793433, 0.95206567]])

# %%
y_hat_test_proba[: ][: , 1]
# Out:
# array([0.92423583, 0.85019704, 0.88515548, ..., 0.97307279, 0.95977633,
#        0.95206567])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]

# %%
y_hat_test_proba
# Out:
# array([0.92423583, 0.85019704, 0.88515548, ..., 0.97307279, 0.95977633,
#        0.95206567])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1          0.924236
# 288564                       1          0.850197
# 213591                       1          0.885155
# 263083                       1          0.938722
# 165001                       1          0.968578

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7383   2807
# 1          35819  47248

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.079168  0.030100
# 1          0.384089  0.506643

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5858112527745907

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990186, 0.99990186,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 4.81538999e-05, ...,
#         9.99975923e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.99256562, 0.99101667, ..., 0.50594177, 0.49513903,
#         0.49481669]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'],
                                 df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
AUROC
# Out:
# 0.7017789162307977

# %% [markdown]
# ### Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba')

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 11208                        0          0.494817           0
# 118702                       1          0.495139           0
# 41663                        1          0.499606           0
# 210472                       0          0.505942           0
# 2808                         0          0.507809           0

# %%
df_actual_predicted_probs.tail()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 261095                       0          0.990635           1
# 231463                       1          0.991017           1
# 239228                       1          0.991254           1
# 261086                       1          0.992052           1
# 242624                       1          0.992566           1

# %%
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()

# %%
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0   11208                       0          0.494817           0
# 1  118702                       1          0.495139           0
# 2   41663                       1          0.499606           0
# 3  210472                       0          0.505942           0
# 4    2808                       0          0.507809           0

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()

# %%
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0   11208                       0          0.494817           0
# 1  118702                       1          0.495139           0
# 2   41663                       1          0.499606           0
# 3  210472                       0          0.505942           0
# 4    2808                       0          0.507809           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / df_actual_predicted_probs['loan_data_targets_test'].sum()
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())

# %%
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0   11208                       0          0.494817           0
# 1  118702                       1          0.495139           0
# 2   41663                       1          0.499606           0
# 3  210472                       0          0.505942           0
# 4    2808                       0          0.507809           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3
#
#    Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 0                    0.000011              0.000000             0.000098
# 1                    0.000021              0.000012             0.000098
# 2                    0.000032              0.000024             0.000098
# 3                    0.000043              0.000024             0.000196
# 4                    0.000054              0.000024             0.000294

# %%
df_actual_predicted_probs.tail()
# Out:
#         index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 93252  261095                       0          0.990635           1
# 93253  231463                       1          0.991017           1
# 93254  239228                       1          0.991254           1
# 93255  261086                       1          0.992052           1
# 93256  242624                       1          0.992566           1
#
#        Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 93252                    93253              83063             10190
# 93253                    93254              83064             10190
# 93254                    93255              83065             10190
# 93255                    93256              83066             10190
# 93256                    93257              83067             10190
#
#        Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 93252                    0.999957              0.999952                  1.0
# 93253                    0.999968              0.999964                  1.0
# 93254                    0.999979              0.999976                  1.0
# 93255                    0.999989              0.999988                  1.0
# 93256                    1.000000              1.000000                  1.0

# %%
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Bad'])
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')
plt.xlabel('Cumulative % Population')
plt.ylabel('Cumulative % Bad')
plt.title('Gini')
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 - 1
Gini
# Out:
# 0.4035578324615954

# %%
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')
plt.xlabel('Estimated Probability for being Good')
plt.ylabel('Cumulative %')
plt.title('Kolmogorov-Smirnov')
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %%
KS = max(df_actual_predicted_probs['Cumulative Perc Bad'] - df_actual_predicted_probs['Cumulative Perc Good'])
KS
# Out:
# 0.2968000044137137

# %% [markdown]
# # Applying the PD Model

# %% [markdown]
# ### Calculating PD of individual accounts

# %%
pd.options.display.max_columns = None

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -0.445985            NaN
# 1                               grade:A      0.944051   4.229369e-25
# 2                               grade:B      0.732144   1.440979e-32
# 3                               grade:C      0.549044   7.371959e-22
# 4                               grade:D      0.373379   5.637468e-12
# 5                               grade:E      0.219520   5.131963e-06
# 6                               grade:F      0.049873   3.185217e-01
# 7                    home_ownership:OWN      0.096256   1.835873e-06
# 8               home_ownership:MORTGAGE      0.105095   9.223599e-17
# 9                      addr_state:NM_VA      0.044426   1.648468e-01
# 10                        addr_state:NY      0.069406   4.138647e-03
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066681   3.919362e-03
# 12                        addr_state:CA      0.073258   5.360600e-04
# 13               addr_state:UT_KY_AZ_NJ      0.088412   3.809330e-04
# 14            addr_state:AR_MI_PA_OH_MN      0.145712   9.345432e-11
# 15            addr_state:RI_MA_DE_SD_IN      0.113471   1.429824e-04
# 16                  addr_state:GA_WA_OR      0.196256   1.782790e-13
# 17                     addr_state:WI_MT      0.243453   2.940800e-07
# 18                        addr_state:TX      0.232289   3.588608e-19
# 19                     addr_state:IL_CT      0.271777   1.263475e-20
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.333680   2.910328e-27
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500647   1.798297e-21
# 22     verification_status:Not Verified      0.080358   3.622018e-08
# 23  verification_status:Source Verified     -0.013063   3.307871e-01
# 24                  purpose:credit_card      0.283008   2.067570e-23
# 25           purpose:debt_consolidation      0.177753   1.012215e-11
# 26           purpose:oth__med__vacation      0.188407   1.518854e-09
# 27  purpose:major_purch__car__home_impr      0.242110   1.019727e-14
# 28                initial_list_status:w      0.049503   1.495693e-04
# 29                              term:36      0.080814   7.416943e-09
# 30                         emp_length:1      0.109079   2.618237e-05
# 31                       emp_length:2-4      0.133383   1.512758e-12
# 32                       emp_length:5-6      0.100128   2.853152e-06
# 33                       emp_length:7-9      0.067128   1.235143e-03
# 34                        emp_length:10      0.130179   1.563383e-12
# 35               mths_since_issue_d:<38      1.133686  9.981814e-203
# 36             mths_since_issue_d:38-39      0.944140  1.063478e-176
# 37             mths_since_issue_d:40-41      0.844111  2.714730e-149
# 38             mths_since_issue_d:42-48      0.652120  5.534130e-115
# 39             mths_since_issue_d:49-52      0.488600   3.162987e-57
# 40             mths_since_issue_d:53-64      0.243540   2.522586e-17
# 41             mths_since_issue_d:65-84     -0.007180   8.031001e-01
# 42                      int_rate:<9.548      0.964427   1.130093e-36
# 43                int_rate:9.548-12.025      0.625920   1.240778e-44
# 44                int_rate:12.025-15.74      0.361330   7.857323e-23
# 45                int_rate:15.74-20.281      0.149165   2.752249e-07
# 46  mths_since_earliest_cr_line:141-164      0.076842   1.987924e-03
# 47  mths_since_earliest_cr_line:165-247      0.057176   4.298403e-03
# 48  mths_since_earliest_cr_line:248-270      0.105623   5.594168e-05
# 49  mths_since_earliest_cr_line:271-352      0.145712   4.603632e-10
# 50     mths_since_earliest_cr_line:>352      0.152760   7.998701e-09
# 51                     inq_last_6mths:0      0.271788   2.863685e-03
# 52                   inq_last_6mths:1-2      0.127122   1.626701e-01
# 53                   inq_last_6mths:3-6     -0.080300   3.806585e-01
# 54                   acc_now_delinq:>=1      0.147718   1.633147e-01
# 55                   annual_inc:20K-30K     -0.179924   2.989982e-05
# 56                   annual_inc:30K-40K     -0.115858   5.255335e-03
# 57                   annual_inc:40K-50K     -0.021146   6.100014e-01
# 58                   annual_inc:50K-60K      0.043639   2.983736e-01
# 59                   annual_inc:60K-70K      0.121916   4.464635e-03
# 60                   annual_inc:70K-80K      0.193073   9.913134e-06
# 61                   annual_inc:80K-90K      0.269304   3.048331e-09
# 62                  annual_inc:90K-100K      0.280046   2.403598e-09
# 63                 annual_inc:100K-120K      0.360420   9.829187e-15
# 64                 annual_inc:120K-140K      0.482019   8.655368e-20
# 65                     annual_inc:>140K      0.386657   1.435115e-15
# 66                            dti:<=1.4      0.059121   4.903890e-01
# 67                          dti:1.4-3.5      0.169936   1.960242e-02
# 68                          dti:3.5-7.7      0.203104   1.432296e-03
# 69                         dti:7.7-10.5      0.136558   3.111326e-02
# 70                        dti:10.5-16.1      0.055871   3.632459e-01
# 71                        dti:16.1-20.3     -0.046006   4.546610e-01
# 72                        dti:20.3-21.7     -0.064257   3.159130e-01
# 73                        dti:21.7-22.4     -0.093388   1.693526e-01
# 74                          dti:22.4-35     -0.137457   2.400711e-02
# 75       mths_since_last_delinq:Missing      0.082870   1.113282e-01
# 76          mths_since_last_delinq:4-30      0.106341   4.345328e-02
# 77         mths_since_last_delinq:31-56      0.150261   4.832156e-03
# 78          mths_since_last_delinq:>=57      0.100756   6.491165e-02
# 79       mths_since_last_record:Missing      0.102070   1.694579e-01
# 80          mths_since_last_record:3-20      0.208104   7.774547e-02
# 81         mths_since_last_record:21-31      0.120604   2.611570e-01
# 82         mths_since_last_record:32-80      0.276375   4.353017e-04
# 83         mths_since_last_record:81-86     -0.091750   2.842163e-01
# 84          mths_since_last_record:>=86     -0.004813   9.494028e-01

# %%
y_hat_test_proba
# Out:
# array([0.92423583, 0.85019704, 0.88515548, ..., 0.97307279, 0.95977633,
#        0.95206567])

# %% [markdown]
# ### Creating a Scorecard

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -0.445985            NaN
# 1                               grade:A      0.944051   4.229369e-25
# 2                               grade:B      0.732144   1.440979e-32
# 3                               grade:C      0.549044   7.371959e-22
# 4                               grade:D      0.373379   5.637468e-12
# 5                               grade:E      0.219520   5.131963e-06
# 6                               grade:F      0.049873   3.185217e-01
# 7                    home_ownership:OWN      0.096256   1.835873e-06
# 8               home_ownership:MORTGAGE      0.105095   9.223599e-17
# 9                      addr_state:NM_VA      0.044426   1.648468e-01
# 10                        addr_state:NY      0.069406   4.138647e-03
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066681   3.919362e-03
# 12                        addr_state:CA      0.073258   5.360600e-04
# 13               addr_state:UT_KY_AZ_NJ      0.088412   3.809330e-04
# 14            addr_state:AR_MI_PA_OH_MN      0.145712   9.345432e-11
# 15            addr_state:RI_MA_DE_SD_IN      0.113471   1.429824e-04
# 16                  addr_state:GA_WA_OR      0.196256   1.782790e-13
# 17                     addr_state:WI_MT      0.243453   2.940800e-07
# 18                        addr_state:TX      0.232289   3.588608e-19
# 19                     addr_state:IL_CT      0.271777   1.263475e-20
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.333680   2.910328e-27
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500647   1.798297e-21
# 22     verification_status:Not Verified      0.080358   3.622018e-08
# 23  verification_status:Source Verified     -0.013063   3.307871e-01
# 24                  purpose:credit_card      0.283008   2.067570e-23
# 25           purpose:debt_consolidation      0.177753   1.012215e-11
# 26           purpose:oth__med__vacation      0.188407   1.518854e-09
# 27  purpose:major_purch__car__home_impr      0.242110   1.019727e-14
# 28                initial_list_status:w      0.049503   1.495693e-04
# 29                              term:36      0.080814   7.416943e-09
# 30                         emp_length:1      0.109079   2.618237e-05
# 31                       emp_length:2-4      0.133383   1.512758e-12
# 32                       emp_length:5-6      0.100128   2.853152e-06
# 33                       emp_length:7-9      0.067128   1.235143e-03
# 34                        emp_length:10      0.130179   1.563383e-12
# 35               mths_since_issue_d:<38      1.133686  9.981814e-203
# 36             mths_since_issue_d:38-39      0.944140  1.063478e-176
# 37             mths_since_issue_d:40-41      0.844111  2.714730e-149
# 38             mths_since_issue_d:42-48      0.652120  5.534130e-115
# 39             mths_since_issue_d:49-52      0.488600   3.162987e-57
# 40             mths_since_issue_d:53-64      0.243540   2.522586e-17
# 41             mths_since_issue_d:65-84     -0.007180   8.031001e-01
# 42                      int_rate:<9.548      0.964427   1.130093e-36
# 43                int_rate:9.548-12.025      0.625920   1.240778e-44
# 44                int_rate:12.025-15.74      0.361330   7.857323e-23
# 45                int_rate:15.74-20.281      0.149165   2.752249e-07
# 46  mths_since_earliest_cr_line:141-164      0.076842   1.987924e-03
# 47  mths_since_earliest_cr_line:165-247      0.057176   4.298403e-03
# 48  mths_since_earliest_cr_line:248-270      0.105623   5.594168e-05
# 49  mths_since_earliest_cr_line:271-352      0.145712   4.603632e-10
# 50     mths_since_earliest_cr_line:>352      0.152760   7.998701e-09
# 51                     inq_last_6mths:0      0.271788   2.863685e-03
# 52                   inq_last_6mths:1-2      0.127122   1.626701e-01
# 53                   inq_last_6mths:3-6     -0.080300   3.806585e-01
# 54                   acc_now_delinq:>=1      0.147718   1.633147e-01
# 55                   annual_inc:20K-30K     -0.179924   2.989982e-05
# 56                   annual_inc:30K-40K     -0.115858   5.255335e-03
# 57                   annual_inc:40K-50K     -0.021146   6.100014e-01
# 58                   annual_inc:50K-60K      0.043639   2.983736e-01
# 59                   annual_inc:60K-70K      0.121916   4.464635e-03
# 60                   annual_inc:70K-80K      0.193073   9.913134e-06
# 61                   annual_inc:80K-90K      0.269304   3.048331e-09
# 62                  annual_inc:90K-100K      0.280046   2.403598e-09
# 63                 annual_inc:100K-120K      0.360420   9.829187e-15
# 64                 annual_inc:120K-140K      0.482019   8.655368e-20
# 65                     annual_inc:>140K      0.386657   1.435115e-15
# 66                            dti:<=1.4      0.059121   4.903890e-01
# 67                          dti:1.4-3.5      0.169936   1.960242e-02
# 68                          dti:3.5-7.7      0.203104   1.432296e-03
# 69                         dti:7.7-10.5      0.136558   3.111326e-02
# 70                        dti:10.5-16.1      0.055871   3.632459e-01
# 71                        dti:16.1-20.3     -0.046006   4.546610e-01
# 72                        dti:20.3-21.7     -0.064257   3.159130e-01
# 73                        dti:21.7-22.4     -0.093388   1.693526e-01
# 74                          dti:22.4-35     -0.137457   2.400711e-02
# 75       mths_since_last_delinq:Missing      0.082870   1.113282e-01
# 76          mths_since_last_delinq:4-30      0.106341   4.345328e-02
# 77         mths_since_last_delinq:31-56      0.150261   4.832156e-03
# 78          mths_since_last_delinq:>=57      0.100756   6.491165e-02
# 79       mths_since_last_record:Missing      0.102070   1.694579e-01
# 80          mths_since_last_record:3-20      0.208104   7.774547e-02
# 81         mths_since_last_record:21-31      0.120604   2.611570e-01
# 82         mths_since_last_record:32-80      0.276375   4.353017e-04
# 83         mths_since_last_record:81-86     -0.091750   2.842163e-01
# 84          mths_since_last_record:>=86     -0.004813   9.494028e-01

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
df_ref_categories['Coefficients'] = 0
df_ref_categories['p_values'] = np.nan
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10              mths_since_earliest_cr_line:<140             0       NaN
# 11                             inq_last_6mths:>6             0       NaN
# 12                              acc_now_delinq:0             0       NaN
# 13                               annual_inc:<20K             0       NaN
# 14                                       dti:>35             0       NaN
# 15                    mths_since_last_delinq:0-3             0       NaN
# 16                    mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
df_scorecard = df_scorecard.reset_index()
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values
# 0              NaN
# 1     4.229369e-25
# 2     1.440979e-32
# 3     7.371959e-22
# 4     5.637468e-12
# 5     5.131963e-06
# 6     3.185217e-01
# 7     1.835873e-06
# 8     9.223599e-17
# 9     1.648468e-01
# 10    4.138647e-03
# 11    3.919362e-03
# 12    5.360600e-04
# 13    3.809330e-04
# 14    9.345432e-11
# 15    1.429824e-04
# 16    1.782790e-13
# 17    2.940800e-07
# 18    3.588608e-19
# 19    1.263475e-20
# 20    2.910328e-27
# 21    1.798297e-21
# 22    3.622018e-08
# 23    3.307871e-01
# 24    2.067570e-23
# 25    1.012215e-11
# 26    1.518854e-09
# 27    1.019727e-14
# 28    1.495693e-04
# 29    7.416943e-09
# 30    2.618237e-05
# 31    1.512758e-12
# 32    2.853152e-06
# 33    1.235143e-03
# 34    1.563383e-12
# 35   9.981814e-203
# 36   1.063478e-176
# 37   2.714730e-149
# 38   5.534130e-115
# 39    3.162987e-57
# 40    2.522586e-17
# 41    8.031001e-01
# 42    1.130093e-36
# 43    1.240778e-44
# 44    7.857323e-23
# 45    2.752249e-07
# 46    1.987924e-03
# 47    4.298403e-03
# 48    5.594168e-05
# 49    4.603632e-10
# 50    7.998701e-09
# 51    2.863685e-03
# 52    1.626701e-01
# 53    3.806585e-01
# 54    1.633147e-01
# 55    2.989982e-05
# 56    5.255335e-03
# 57    6.100014e-01
# 58    2.983736e-01
# 59    4.464635e-03
# 60    9.913134e-06
# 61    3.048331e-09
# 62    2.403598e-09
# 63    9.829187e-15
# 64    8.655368e-20
# 65    1.435115e-15
# 66    4.903890e-01
# 67    1.960242e-02
# 68    1.432296e-03
# 69    3.111326e-02
# 70    3.632459e-01
# 71    4.546610e-01
# 72    3.159130e-01
# 73    1.693526e-01
# 74    2.400711e-02
# 75    1.113282e-01
# 76    4.345328e-02
# 77    4.832156e-03
# 78    6.491165e-02
# 79    1.694579e-01
# 80    7.774547e-02
# 81    2.611570e-01
# 82    4.353017e-04
# 83    2.842163e-01
# 84    9.494028e-01
# 85             NaN
# 86             NaN
# 87             NaN
# 88             NaN
# 89             NaN
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# 100            NaN
# 101            NaN

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name
# 0              NaN                    Intercept
# 1     4.229369e-25                        grade
# 2     1.440979e-32                        grade
# 3     7.371959e-22                        grade
# 4     5.637468e-12                        grade
# 5     5.131963e-06                        grade
# 6     3.185217e-01                        grade
# 7     1.835873e-06               home_ownership
# 8     9.223599e-17               home_ownership
# 9     1.648468e-01                   addr_state
# 10    4.138647e-03                   addr_state
# 11    3.919362e-03                   addr_state
# 12    5.360600e-04                   addr_state
# 13    3.809330e-04                   addr_state
# 14    9.345432e-11                   addr_state
# 15    1.429824e-04                   addr_state
# 16    1.782790e-13                   addr_state
# 17    2.940800e-07                   addr_state
# 18    3.588608e-19                   addr_state
# 19    1.263475e-20                   addr_state
# 20    2.910328e-27                   addr_state
# 21    1.798297e-21                   addr_state
# 22    3.622018e-08          verification_status
# 23    3.307871e-01          verification_status
# 24    2.067570e-23                      purpose
# 25    1.012215e-11                      purpose
# 26    1.518854e-09                      purpose
# 27    1.019727e-14                      purpose
# 28    1.495693e-04          initial_list_status
# 29    7.416943e-09                         term
# 30    2.618237e-05                   emp_length
# 31    1.512758e-12                   emp_length
# 32    2.853152e-06                   emp_length
# 33    1.235143e-03                   emp_length
# 34    1.563383e-12                   emp_length
# 35   9.981814e-203           mths_since_issue_d
# 36   1.063478e-176           mths_since_issue_d
# 37   2.714730e-149           mths_since_issue_d
# 38   5.534130e-115           mths_since_issue_d
# 39    3.162987e-57           mths_since_issue_d
# 40    2.522586e-17           mths_since_issue_d
# 41    8.031001e-01           mths_since_issue_d
# 42    1.130093e-36                     int_rate
# 43    1.240778e-44                     int_rate
# 44    7.857323e-23                     int_rate
# 45    2.752249e-07                     int_rate
# 46    1.987924e-03  mths_since_earliest_cr_line
# 47    4.298403e-03  mths_since_earliest_cr_line
# 48    5.594168e-05  mths_since_earliest_cr_line
# 49    4.603632e-10  mths_since_earliest_cr_line
# 50    7.998701e-09  mths_since_earliest_cr_line
# 51    2.863685e-03               inq_last_6mths
# 52    1.626701e-01               inq_last_6mths
# 53    3.806585e-01               inq_last_6mths
# 54    1.633147e-01               acc_now_delinq
# 55    2.989982e-05                   annual_inc
# 56    5.255335e-03                   annual_inc
# 57    6.100014e-01                   annual_inc
# 58    2.983736e-01                   annual_inc
# 59    4.464635e-03                   annual_inc
# 60    9.913134e-06                   annual_inc
# 61    3.048331e-09                   annual_inc
# 62    2.403598e-09                   annual_inc
# 63    9.829187e-15                   annual_inc
# 64    8.655368e-20                   annual_inc
# 65    1.435115e-15                   annual_inc
# 66    4.903890e-01                          dti
# 67    1.960242e-02                          dti
# 68    1.432296e-03                          dti
# 69    3.111326e-02                          dti
# 70    3.632459e-01                          dti
# 71    4.546610e-01                          dti
# 72    3.159130e-01                          dti
# 73    1.693526e-01                          dti
# 74    2.400711e-02                          dti
# 75    1.113282e-01       mths_since_last_delinq
# 76    4.345328e-02       mths_since_last_delinq
# 77    4.832156e-03       mths_since_last_delinq
# 78    6.491165e-02       mths_since_last_delinq
# 79    1.694579e-01       mths_since_last_record
# 80    7.774547e-02       mths_since_last_record
# 81    2.611570e-01       mths_since_last_record
# 82    4.353017e-04       mths_since_last_record
# 83    2.842163e-01       mths_since_last_record
# 84    9.494028e-01       mths_since_last_record
# 85             NaN                        grade
# 86             NaN               home_ownership
# 87             NaN                   addr_state
# 88             NaN          verification_status
# 89             NaN                      purpose
# 90             NaN          initial_list_status
# 91             NaN                         term
# 92             NaN                   emp_length
# 93             NaN           mths_since_issue_d
# 94             NaN                     int_rate
# 95             NaN  mths_since_earliest_cr_line
# 96             NaN               inq_last_6mths
# 97             NaN               acc_now_delinq
# 98             NaN                   annual_inc
# 99             NaN                          dti
# 100            NaN       mths_since_last_delinq
# 101            NaN       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Out:
# Original feature name
# Intercept                     -0.445985
# acc_now_delinq                 0.000000
# addr_state                     0.000000
# annual_inc                    -0.179924
# dti                           -0.137457
# emp_length                     0.000000
# grade                          0.000000
# home_ownership                 0.000000
# initial_list_status            0.000000
# inq_last_6mths                -0.080300
# int_rate                       0.000000
# mths_since_earliest_cr_line    0.000000
# mths_since_issue_d            -0.007180
# mths_since_last_delinq         0.000000
# mths_since_last_record        -0.091750
# purpose                        0.000000
# term                           0.000000
# verification_status           -0.013063
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
min_sum_coef
# Out:
# -0.9556596161319548

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Out:
# Original feature name
# Intercept                     -0.445985
# acc_now_delinq                 0.147718
# addr_state                     0.500647
# annual_inc                     0.482019
# dti                            0.203104
# emp_length                     0.133383
# grade                          0.944051
# home_ownership                 0.105095
# initial_list_status            0.049503
# inq_last_6mths                 0.271788
# int_rate                       0.964427
# mths_since_earliest_cr_line    0.152760
# mths_since_issue_d             1.133686
# mths_since_last_delinq         0.150261
# mths_since_last_record         0.276375
# purpose                        0.283008
# term                           0.080814
# verification_status            0.080358
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
max_sum_coef
# Out:
# 5.51301099780484

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           -37.919935
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
df_scorecard
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\1263832758.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\1263832758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           343.335213
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           343.335213
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary
# 0                  343.0
# 1                   80.0
# 2                   62.0
# 3                   47.0
# 4                   32.0
# 5                   19.0
# 6                    4.0
# 7                    8.0
# 8                    9.0
# 9                    4.0
# 10                   6.0
# 11                   6.0
# 12                   6.0
# 13                   8.0
# 14                  12.0
# 15                  10.0
# 16                  17.0
# 17                  21.0
# 18                  20.0
# 19                  23.0
# 20                  28.0
# 21                  43.0
# 22                   7.0
# 23                  -1.0
# 24                  24.0
# 25                  15.0
# 26                  16.0
# 27                  21.0
# 28                   4.0
# 29                   7.0
# 30                   9.0
# 31                  11.0
# 32                   9.0
# 33                   6.0
# 34                  11.0
# 35                  96.0
# 36                  80.0
# 37                  72.0
# 38                  55.0
# 39                  42.0
# 40                  21.0
# 41                  -1.0
# 42                  82.0
# 43                  53.0
# 44                  31.0
# 45                  13.0
# 46                   7.0
# 47                   5.0
# 48                   9.0
# 49                  12.0
# 50                  13.0
# 51                  23.0
# 52                  11.0
# 53                  -7.0
# 54                  13.0
# 55                 -15.0
# 56                 -10.0
# 57                  -2.0
# 58                   4.0
# 59                  10.0
# 60                  16.0
# 61                  23.0
# 62                  24.0
# 63                  31.0
# 64                  41.0
# 65                  33.0
# 66                   5.0
# 67                  14.0
# 68                  17.0
# 69                  12.0
# 70                   5.0
# 71                  -4.0
# 72                  -5.0
# 73                  -8.0
# 74                 -12.0
# 75                   7.0
# 76                   9.0
# 77                  13.0
# 78                   9.0
# 79                   9.0
# 80                  18.0
# 81                  10.0
# 82                  23.0
# 83                  -8.0
# 84                  -0.0
# 85                   0.0
# 86                   0.0
# 87                   0.0
# 88                   0.0
# 89                   0.0
# 90                   0.0
# 91                   0.0
# 92                   0.0
# 93                   0.0
# 94                   0.0
# 95                   0.0
# 96                   0.0
# 97                   0.0
# 98                   0.0
# 99                   0.0
# 100                  0.0
# 101                  0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
min_sum_score_prel
# Out:
# 299.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max(). sum()
max_sum_score_prel
# Out:
# 849.0

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           343.335213
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference
# 0                  343.0   -0.335213
# 1                   80.0   -0.268148
# 2                   62.0   -0.250667
# 3                   47.0    0.317438
# 4                   32.0    0.253368
# 5                   19.0    0.335252
# 6                    4.0   -0.240478
# 7                    8.0   -0.184147
# 8                    9.0    0.064285
# 9                    4.0    0.222658
# 10                   6.0    0.098708
# 11                   6.0    0.330393
# 12                   6.0   -0.228809
# 13                   8.0    0.482740
# 14                  12.0   -0.389187
# 15                  10.0    0.352123
# 16                  17.0    0.313315
# 17                  21.0    0.300359
# 18                  20.0    0.249609
# 19                  23.0   -0.107929
# 20                  28.0   -0.371241
# 21                  43.0    0.432413
# 22                   7.0    0.167529
# 23                  -1.0    0.110723
# 24                  24.0   -0.062782
# 25                  15.0   -0.113461
# 26                  16.0   -0.019316
# 27                  21.0    0.414531
# 28                   4.0   -0.209042
# 29                   7.0    0.128798
# 30                   9.0   -0.274479
# 31                  11.0   -0.340932
# 32                   9.0    0.486616
# 33                   6.0    0.292431
# 34                  11.0   -0.068495
# 35                  96.0   -0.391871
# 36                  80.0   -0.275689
# 37                  72.0    0.229320
# 38                  55.0   -0.446612
# 39                  42.0    0.456689
# 40                  21.0    0.292926
# 41                  -1.0   -0.389499
# 42                  82.0   -0.000555
# 43                  53.0   -0.218998
# 44                  31.0    0.277840
# 45                  13.0    0.317243
# 46                   7.0    0.466469
# 47                   5.0    0.138604
# 48                   9.0    0.019413
# 49                  12.0   -0.389170
# 50                  13.0    0.011593
# 51                  23.0   -0.108818
# 52                  11.0    0.191420
# 53                  -7.0   -0.172499
# 54                  13.0    0.440248
# 55                 -15.0    0.298093
# 56                 -10.0   -0.149181
# 57                  -2.0   -0.202024
# 58                   4.0    0.289594
# 59                  10.0   -0.365918
# 60                  16.0   -0.416047
# 61                  23.0    0.102358
# 62                  24.0    0.189004
# 63                  31.0    0.355208
# 64                  41.0    0.016253
# 65                  33.0    0.124451
# 66                   5.0   -0.026816
# 67                  14.0   -0.448815
# 68                  17.0   -0.268953
# 69                  12.0    0.389109
# 70                   5.0    0.249550
# 71                  -4.0   -0.088310
# 72                  -5.0    0.463460
# 73                  -8.0   -0.059704
# 74                 -12.0   -0.312703
# 75                   7.0   -0.046070
# 76                   9.0   -0.041704
# 77                  13.0    0.224037
# 78                   9.0    0.433193
# 79                   9.0    0.321469
# 80                  18.0    0.305887
# 81                  10.0   -0.254397
# 82                  23.0   -0.498842
# 83                  -8.0   -0.198902
# 84                  -0.0    0.409208
# 85                   0.0    0.000000
# 86                   0.0    0.000000
# 87                   0.0    0.000000
# 88                   0.0    0.000000
# 89                   0.0    0.000000
# 90                   0.0    0.000000
# 91                   0.0    0.000000
# 92                   0.0    0.000000
# 93                   0.0    0.000000
# 94                   0.0    0.000000
# 95                   0.0    0.000000
# 96                   0.0    0.000000
# 97                   0.0    0.000000
# 98                   0.0    0.000000
# 99                   0.0    0.000000
# 100                  0.0    0.000000
# 101                  0.0    0.000000

# %%
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][77] = 16
df_scorecard
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\1528914224.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_scorecard['Score - Final'][77] = 16
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\1528914224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][77] = 16
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           343.335213
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  343.0   -0.335213          343.0
# 1                   80.0   -0.268148           80.0
# 2                   62.0   -0.250667           62.0
# 3                   47.0    0.317438           47.0
# 4                   32.0    0.253368           32.0
# 5                   19.0    0.335252           19.0
# 6                    4.0   -0.240478            4.0
# 7                    8.0   -0.184147            8.0
# 8                    9.0    0.064285            9.0
# 9                    4.0    0.222658            4.0
# 10                   6.0    0.098708            6.0
# 11                   6.0    0.330393            6.0
# 12                   6.0   -0.228809            6.0
# 13                   8.0    0.482740            8.0
# 14                  12.0   -0.389187           12.0
# 15                  10.0    0.352123           10.0
# 16                  17.0    0.313315           17.0
# 17                  21.0    0.300359           21.0
# 18                  20.0    0.249609           20.0
# 19                  23.0   -0.107929           23.0
# 20                  28.0   -0.371241           28.0
# 21                  43.0    0.432413           43.0
# 22                   7.0    0.167529            7.0
# 23                  -1.0    0.110723           -1.0
# 24                  24.0   -0.062782           24.0
# 25                  15.0   -0.113461           15.0
# 26                  16.0   -0.019316           16.0
# 27                  21.0    0.414531           21.0
# 28                   4.0   -0.209042            4.0
# 29                   7.0    0.128798            7.0
# 30                   9.0   -0.274479            9.0
# 31                  11.0   -0.340932           11.0
# 32                   9.0    0.486616            9.0
# 33                   6.0    0.292431            6.0
# 34                  11.0   -0.068495           11.0
# 35                  96.0   -0.391871           96.0
# 36                  80.0   -0.275689           80.0
# 37                  72.0    0.229320           72.0
# 38                  55.0   -0.446612           55.0
# 39                  42.0    0.456689           42.0
# 40                  21.0    0.292926           21.0
# 41                  -1.0   -0.389499           -1.0
# 42                  82.0   -0.000555           82.0
# 43                  53.0   -0.218998           53.0
# 44                  31.0    0.277840           31.0
# 45                  13.0    0.317243           13.0
# 46                   7.0    0.466469            7.0
# 47                   5.0    0.138604            5.0
# 48                   9.0    0.019413            9.0
# 49                  12.0   -0.389170           12.0
# 50                  13.0    0.011593           13.0
# 51                  23.0   -0.108818           23.0
# 52                  11.0    0.191420           11.0
# 53                  -7.0   -0.172499           -7.0
# 54                  13.0    0.440248           13.0
# 55                 -15.0    0.298093          -15.0
# 56                 -10.0   -0.149181          -10.0
# 57                  -2.0   -0.202024           -2.0
# 58                   4.0    0.289594            4.0
# 59                  10.0   -0.365918           10.0
# 60                  16.0   -0.416047           16.0
# 61                  23.0    0.102358           23.0
# 62                  24.0    0.189004           24.0
# 63                  31.0    0.355208           31.0
# 64                  41.0    0.016253           41.0
# 65                  33.0    0.124451           33.0
# 66                   5.0   -0.026816            5.0
# 67                  14.0   -0.448815           14.0
# 68                  17.0   -0.268953           17.0
# 69                  12.0    0.389109           12.0
# 70                   5.0    0.249550            5.0
# 71                  -4.0   -0.088310           -4.0
# 72                  -5.0    0.463460           -5.0
# 73                  -8.0   -0.059704           -8.0
# 74                 -12.0   -0.312703          -12.0
# 75                   7.0   -0.046070            7.0
# 76                   9.0   -0.041704            9.0
# 77                  13.0    0.224037           16.0
# 78                   9.0    0.433193            9.0
# 79                   9.0    0.321469            9.0
# 80                  18.0    0.305887           18.0
# 81                  10.0   -0.254397           10.0
# 82                  23.0   -0.498842           23.0
# 83                  -8.0   -0.198902           -8.0
# 84                  -0.0    0.409208           -0.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0
# 101                  0.0    0.000000            0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
min_sum_score_prel
# Out:
# 299.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max(). sum()
max_sum_score_prel
# Out:
# 852.0

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -0.445985
# 1        1                                       grade:A      0.944051
# 2        2                                       grade:B      0.732144
# 3        3                                       grade:C      0.549044
# 4        4                                       grade:D      0.373379
# 5        5                                       grade:E      0.219520
# 6        6                                       grade:F      0.049873
# 7        7                            home_ownership:OWN      0.096256
# 8        8                       home_ownership:MORTGAGE      0.105095
# 9        9                              addr_state:NM_VA      0.044426
# 10      10                                 addr_state:NY      0.069406
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.066681
# 12      12                                 addr_state:CA      0.073258
# 13      13                        addr_state:UT_KY_AZ_NJ      0.088412
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.145712
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.113471
# 16      16                           addr_state:GA_WA_OR      0.196256
# 17      17                              addr_state:WI_MT      0.243453
# 18      18                                 addr_state:TX      0.232289
# 19      19                              addr_state:IL_CT      0.271777
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.333680
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.500647
# 22      22              verification_status:Not Verified      0.080358
# 23      23           verification_status:Source Verified     -0.013063
# 24      24                           purpose:credit_card      0.283008
# 25      25                    purpose:debt_consolidation      0.177753
# 26      26                    purpose:oth__med__vacation      0.188407
# 27      27           purpose:major_purch__car__home_impr      0.242110
# 28      28                         initial_list_status:w      0.049503
# 29      29                                       term:36      0.080814
# 30      30                                  emp_length:1      0.109079
# 31      31                                emp_length:2-4      0.133383
# 32      32                                emp_length:5-6      0.100128
# 33      33                                emp_length:7-9      0.067128
# 34      34                                 emp_length:10      0.130179
# 35      35                        mths_since_issue_d:<38      1.133686
# 36      36                      mths_since_issue_d:38-39      0.944140
# 37      37                      mths_since_issue_d:40-41      0.844111
# 38      38                      mths_since_issue_d:42-48      0.652120
# 39      39                      mths_since_issue_d:49-52      0.488600
# 40      40                      mths_since_issue_d:53-64      0.243540
# 41      41                      mths_since_issue_d:65-84     -0.007180
# 42      42                               int_rate:<9.548      0.964427
# 43      43                         int_rate:9.548-12.025      0.625920
# 44      44                         int_rate:12.025-15.74      0.361330
# 45      45                         int_rate:15.74-20.281      0.149165
# 46      46           mths_since_earliest_cr_line:141-164      0.076842
# 47      47           mths_since_earliest_cr_line:165-247      0.057176
# 48      48           mths_since_earliest_cr_line:248-270      0.105623
# 49      49           mths_since_earliest_cr_line:271-352      0.145712
# 50      50              mths_since_earliest_cr_line:>352      0.152760
# 51      51                              inq_last_6mths:0      0.271788
# 52      52                            inq_last_6mths:1-2      0.127122
# 53      53                            inq_last_6mths:3-6     -0.080300
# 54      54                            acc_now_delinq:>=1      0.147718
# 55      55                            annual_inc:20K-30K     -0.179924
# 56      56                            annual_inc:30K-40K     -0.115858
# 57      57                            annual_inc:40K-50K     -0.021146
# 58      58                            annual_inc:50K-60K      0.043639
# 59      59                            annual_inc:60K-70K      0.121916
# 60      60                            annual_inc:70K-80K      0.193073
# 61      61                            annual_inc:80K-90K      0.269304
# 62      62                           annual_inc:90K-100K      0.280046
# 63      63                          annual_inc:100K-120K      0.360420
# 64      64                          annual_inc:120K-140K      0.482019
# 65      65                              annual_inc:>140K      0.386657
# 66      66                                     dti:<=1.4      0.059121
# 67      67                                   dti:1.4-3.5      0.169936
# 68      68                                   dti:3.5-7.7      0.203104
# 69      69                                  dti:7.7-10.5      0.136558
# 70      70                                 dti:10.5-16.1      0.055871
# 71      71                                 dti:16.1-20.3     -0.046006
# 72      72                                 dti:20.3-21.7     -0.064257
# 73      73                                 dti:21.7-22.4     -0.093388
# 74      74                                   dti:22.4-35     -0.137457
# 75      75                mths_since_last_delinq:Missing      0.082870
# 76      76                   mths_since_last_delinq:4-30      0.106341
# 77      77                  mths_since_last_delinq:31-56      0.150261
# 78      78                   mths_since_last_delinq:>=57      0.100756
# 79      79                mths_since_last_record:Missing      0.102070
# 80      80                   mths_since_last_record:3-20      0.208104
# 81      81                  mths_since_last_record:21-31      0.120604
# 82      82                  mths_since_last_record:32-80      0.276375
# 83      83                  mths_since_last_record:81-86     -0.091750
# 84      84                   mths_since_last_record:>=86     -0.004813
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           343.335213
# 1     4.229369e-25                        grade            80.268148
# 2     1.440979e-32                        grade            62.250667
# 3     7.371959e-22                        grade            46.682562
# 4     5.637468e-12                        grade            31.746632
# 5     5.131963e-06                        grade            18.664748
# 6     3.185217e-01                        grade             4.240478
# 7     1.835873e-06               home_ownership             8.184147
# 8     9.223599e-17               home_ownership             8.935715
# 9     1.648468e-01                   addr_state             3.777342
# 10    4.138647e-03                   addr_state             5.901292
# 11    3.919362e-03                   addr_state             5.669607
# 12    5.360600e-04                   addr_state             6.228809
# 13    3.809330e-04                   addr_state             7.517260
# 14    9.345432e-11                   addr_state            12.389187
# 15    1.429824e-04                   addr_state             9.647877
# 16    1.782790e-13                   addr_state            16.686685
# 17    2.940800e-07                   addr_state            20.699641
# 18    3.588608e-19                   addr_state            19.750391
# 19    1.263475e-20                   addr_state            23.107929
# 20    2.910328e-27                   addr_state            28.371241
# 21    1.798297e-21                   addr_state            42.567587
# 22    3.622018e-08          verification_status             6.832471
# 23    3.307871e-01          verification_status            -1.110723
# 24    2.067570e-23                      purpose            24.062782
# 25    1.012215e-11                      purpose            15.113461
# 26    1.518854e-09                      purpose            16.019316
# 27    1.019727e-14                      purpose            20.585469
# 28    1.495693e-04          initial_list_status             4.209042
# 29    7.416943e-09                         term             6.871202
# 30    2.618237e-05                   emp_length             9.274479
# 31    1.512758e-12                   emp_length            11.340932
# 32    2.853152e-06                   emp_length             8.513384
# 33    1.235143e-03                   emp_length             5.707569
# 34    1.563383e-12                   emp_length            11.068495
# 35   9.981814e-203           mths_since_issue_d            96.391871
# 36   1.063478e-176           mths_since_issue_d            80.275689
# 37   2.714730e-149           mths_since_issue_d            71.770680
# 38   5.534130e-115           mths_since_issue_d            55.446612
# 39    3.162987e-57           mths_since_issue_d            41.543311
# 40    2.522586e-17           mths_since_issue_d            20.707074
# 41    8.031001e-01           mths_since_issue_d            -0.610501
# 42    1.130093e-36                     int_rate            82.000555
# 43    1.240778e-44                     int_rate            53.218998
# 44    7.857323e-23                     int_rate            30.722160
# 45    2.752249e-07                     int_rate            12.682757
# 46    1.987924e-03  mths_since_earliest_cr_line             6.533531
# 47    4.298403e-03  mths_since_earliest_cr_line             4.861396
# 48    5.594168e-05  mths_since_earliest_cr_line             8.980587
# 49    4.603632e-10  mths_since_earliest_cr_line            12.389170
# 50    7.998701e-09  mths_since_earliest_cr_line            12.988407
# 51    2.863685e-03               inq_last_6mths            23.108818
# 52    1.626701e-01               inq_last_6mths            10.808580
# 53    3.806585e-01               inq_last_6mths            -6.827501
# 54    1.633147e-01               acc_now_delinq            12.559752
# 55    2.989982e-05                   annual_inc           -15.298093
# 56    5.255335e-03                   annual_inc            -9.850819
# 57    6.100014e-01                   annual_inc            -1.797976
# 58    2.983736e-01                   annual_inc             3.710406
# 59    4.464635e-03                   annual_inc            10.365918
# 60    9.913134e-06                   annual_inc            16.416047
# 61    3.048331e-09                   annual_inc            22.897642
# 62    2.403598e-09                   annual_inc            23.810996
# 63    9.829187e-15                   annual_inc            30.644792
# 64    8.655368e-20                   annual_inc            40.983747
# 65    1.435115e-15                   annual_inc            32.875549
# 66    4.903890e-01                          dti             5.026816
# 67    1.960242e-02                          dti            14.448815
# 68    1.432296e-03                          dti            17.268953
# 69    3.111326e-02                          dti            11.610891
# 70    3.632459e-01                          dti             4.750450
# 71    4.546610e-01                          dti            -3.911690
# 72    3.159130e-01                          dti            -5.463460
# 73    1.693526e-01                          dti            -7.940296
# 74    2.400711e-02                          dti           -11.687297
# 75    1.113282e-01       mths_since_last_delinq             7.046070
# 76    4.345328e-02       mths_since_last_delinq             9.041704
# 77    4.832156e-03       mths_since_last_delinq            12.775963
# 78    6.491165e-02       mths_since_last_delinq             8.566807
# 79    1.694579e-01       mths_since_last_record             8.678531
# 80    7.774547e-02       mths_since_last_record            17.694113
# 81    2.611570e-01       mths_since_last_record            10.254397
# 82    4.353017e-04       mths_since_last_record            23.498842
# 83    2.842163e-01       mths_since_last_record            -7.801098
# 84    9.494028e-01       mths_since_last_record            -0.409208
# 85             NaN                        grade             0.000000
# 86             NaN               home_ownership             0.000000
# 87             NaN                   addr_state             0.000000
# 88             NaN          verification_status             0.000000
# 89             NaN                      purpose             0.000000
# 90             NaN          initial_list_status             0.000000
# 91             NaN                         term             0.000000
# 92             NaN                   emp_length             0.000000
# 93             NaN           mths_since_issue_d             0.000000
# 94             NaN                     int_rate             0.000000
# 95             NaN  mths_since_earliest_cr_line             0.000000
# 96             NaN               inq_last_6mths             0.000000
# 97             NaN               acc_now_delinq             0.000000
# 98             NaN                   annual_inc             0.000000
# 99             NaN                          dti             0.000000
# 100            NaN       mths_since_last_delinq             0.000000
# 101            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  343.0   -0.335213          343.0
# 1                   80.0   -0.268148           80.0
# 2                   62.0   -0.250667           62.0
# 3                   47.0    0.317438           47.0
# 4                   32.0    0.253368           32.0
# 5                   19.0    0.335252           19.0
# 6                    4.0   -0.240478            4.0
# 7                    8.0   -0.184147            8.0
# 8                    9.0    0.064285            9.0
# 9                    4.0    0.222658            4.0
# 10                   6.0    0.098708            6.0
# 11                   6.0    0.330393            6.0
# 12                   6.0   -0.228809            6.0
# 13                   8.0    0.482740            8.0
# 14                  12.0   -0.389187           12.0
# 15                  10.0    0.352123           10.0
# 16                  17.0    0.313315           17.0
# 17                  21.0    0.300359           21.0
# 18                  20.0    0.249609           20.0
# 19                  23.0   -0.107929           23.0
# 20                  28.0   -0.371241           28.0
# 21                  43.0    0.432413           43.0
# 22                   7.0    0.167529            7.0
# 23                  -1.0    0.110723           -1.0
# 24                  24.0   -0.062782           24.0
# 25                  15.0   -0.113461           15.0
# 26                  16.0   -0.019316           16.0
# 27                  21.0    0.414531           21.0
# 28                   4.0   -0.209042            4.0
# 29                   7.0    0.128798            7.0
# 30                   9.0   -0.274479            9.0
# 31                  11.0   -0.340932           11.0
# 32                   9.0    0.486616            9.0
# 33                   6.0    0.292431            6.0
# 34                  11.0   -0.068495           11.0
# 35                  96.0   -0.391871           96.0
# 36                  80.0   -0.275689           80.0
# 37                  72.0    0.229320           72.0
# 38                  55.0   -0.446612           55.0
# 39                  42.0    0.456689           42.0
# 40                  21.0    0.292926           21.0
# 41                  -1.0   -0.389499           -1.0
# 42                  82.0   -0.000555           82.0
# 43                  53.0   -0.218998           53.0
# 44                  31.0    0.277840           31.0
# 45                  13.0    0.317243           13.0
# 46                   7.0    0.466469            7.0
# 47                   5.0    0.138604            5.0
# 48                   9.0    0.019413            9.0
# 49                  12.0   -0.389170           12.0
# 50                  13.0    0.011593           13.0
# 51                  23.0   -0.108818           23.0
# 52                  11.0    0.191420           11.0
# 53                  -7.0   -0.172499           -7.0
# 54                  13.0    0.440248           13.0
# 55                 -15.0    0.298093          -15.0
# 56                 -10.0   -0.149181          -10.0
# 57                  -2.0   -0.202024           -2.0
# 58                   4.0    0.289594            4.0
# 59                  10.0   -0.365918           10.0
# 60                  16.0   -0.416047           16.0
# 61                  23.0    0.102358           23.0
# 62                  24.0    0.189004           24.0
# 63                  31.0    0.355208           31.0
# 64                  41.0    0.016253           41.0
# 65                  33.0    0.124451           33.0
# 66                   5.0   -0.026816            5.0
# 67                  14.0   -0.448815           14.0
# 68                  17.0   -0.268953           17.0
# 69                  12.0    0.389109           12.0
# 70                   5.0    0.249550            5.0
# 71                  -4.0   -0.088310           -4.0
# 72                  -5.0    0.463460           -5.0
# 73                  -8.0   -0.059704           -8.0
# 74                 -12.0   -0.312703          -12.0
# 75                   7.0   -0.046070            7.0
# 76                   9.0   -0.041704            9.0
# 77                  13.0    0.224037           16.0
# 78                   9.0    0.433193            9.0
# 79                   9.0    0.321469            9.0
# 80                  18.0    0.305887           18.0
# 81                  10.0   -0.254397           10.0
# 82                  23.0   -0.498842           23.0
# 83                  -8.0   -0.198902           -8.0
# 84                  -0.0    0.409208           -0.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0
# 101                  0.0    0.000000            0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514        0                                   0                   0
# 288564        0                                   0                   0
# 213591        0                                   0                   0
# 263083        0                                   0                   0
# 165001        0                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86
# 362514                             0                            0
# 288564                             0                            0
# 213591                             0                            0
# 263083                             0                            0
# 165001                             0                            0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      1                      0
# 288564                      0                      0
# 213591                      1                      0
# 263083                      1                      0
# 165001                      0                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0              0            0
# 288564              0              0              0            1
# 213591              0              0              0            0
# 263083              1              0              0            0
# 165001              0              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>=86  grade:G  \
# 362514                             0                            0        0
# 288564                             0                            0        0
# 213591                             0                            0        0
# 263083                             0                            0        0
# 165001                             0                            0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                                   0                                0
# 288564                                   0                                0
# 213591                                   0                                0
# 263083                                   0                                0
# 165001                                   0                                0
#
#         verification_status:Verified  \
# 362514                             1
# 288564                             1
# 213591                             1
# 263083                             0
# 165001                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 362514                                             0                      1
# 288564                                             0                      0
# 213591                                             0                      1
# 263083                                             0                      0
# 165001                                             0                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 362514        1             1                       0                 0
# 288564        1             0                       0                 1
# 213591        0             0                       0                 0
# 263083        1             0                       0                 0
# 165001        0             0                       0                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                                 0                  0                 1
# 288564                                 0                  0                 1
# 213591                                 0                  0                 1
# 263083                                 1                  0                 1
# 165001                                 0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 362514                0        0                           0
# 288564                0        0                           1
# 213591                0        0                           0
# 263083                0        0                           0
# 165001                0        0                           0
#
#         mths_since_last_record:0-2
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 102)

# %%
scorecard_scores.shape
# Out:
# (102,)

# %%
scorecard_scores = scorecard_scores.values.reshape(102, 1)

# %%
scorecard_scores.shape
# Out:
# (102, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)

# %%
y_scores.head()
# Out:
#             0
# 362514  595.0
# 288564  529.0
# 213591  559.0
# 263083  612.0
# 165001  676.0

# %%
y_scores.tail()
# Out:
#             0
# 115     551.0
# 296284  665.0
# 61777   687.0
# 91763   652.0
# 167512  635.0

# %% [markdown]
# ### From Credit Score to PD

# %%
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
y_hat_proba_from_score.head()
# Out:
#                0
# 362514  0.925111
# 288564  0.850390
# 213591  0.889976
# 263083  0.937838
# 165001  0.969721

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.92423583, 0.85019704, 0.88515548, 0.93872185, 0.96857818])

# %%
df_actual_predicted_probs['y_hat_test_proba'].head()
# Out:
# 0    0.494817
# 1    0.495139
# 2    0.499606
# 3    0.505942
# 4    0.507809
# Name: y_hat_test_proba, dtype: float64

# %% [markdown]
# ### Setting Cut-offs

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7383   2807
# 1          35819  47248

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.079168  0.030100
# 1          0.384089  0.506643

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5858112527745907

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990186, 0.99990186,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 4.81538999e-05, ...,
#         9.99975923e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.99256562, 0.99101667, ..., 0.50594177, 0.49513903,
#         0.49481669]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'],
                                 df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
thresholds
# Out:
# array([       inf, 0.99256562, 0.99101667, ..., 0.50594177, 0.49513903,
#        0.49481669])

# %%
thresholds.shape
# Out:
# (17444,)

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)

# %%
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr
# 0         inf  0.000000  0.000000
# 1    0.992566  0.000000  0.000012
# 2    0.991017  0.000000  0.000048
# 3    0.990635  0.000098  0.000048
# 4    0.989188  0.000098  0.000554

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\3197044947.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)

# %%
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr   Score
# 0    1.000000  0.000000  0.000000  2197.0
# 1    0.992566  0.000000  0.000012   797.0
# 2    0.991017  0.000000  0.000048   781.0
# 3    0.990635  0.000098  0.000048   778.0
# 4    0.989188  0.000098  0.000554   765.0

# %%
df_cutoffs['Score'][0] = max_score
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9616\3137964156.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cutoffs['Score'][0] = max_score

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score
# 0    1.000000  0.000000  0.000000  850.0
# 1    0.992566  0.000000  0.000012  797.0
# 2    0.991017  0.000000  0.000048  781.0
# 3    0.990635  0.000098  0.000048  778.0
# 4    0.989188  0.000098  0.000554  765.0

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score
# 17439    0.527945  0.999509  0.999940  391.0
# 17440    0.525426  0.999509  0.999976  390.0
# 17441    0.505942  0.999902  0.999976  383.0
# 17442    0.495139  0.999902  1.000000  380.0
# 17443    0.494817  1.000000  1.000000  379.0

# %%
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]
df_cutoffs['Rejection Rate'] = 1 - df_cutoffs['Approval Rate']

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 0    1.000000  0.000000  0.000000  850.0           0       93257
# 1    0.992566  0.000000  0.000012  797.0           1       93256
# 2    0.991017  0.000000  0.000048  781.0           4       93253
# 3    0.990635  0.000098  0.000048  778.0           5       93252
# 4    0.989188  0.000098  0.000554  765.0          47       93210
#
#    Approval Rate  Rejection Rate
# 0       0.000000        1.000000
# 1       0.000011        0.999989
# 2       0.000043        0.999957
# 3       0.000054        0.999946
# 4       0.000504        0.999496

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 17439    0.527945  0.999509  0.999940  391.0       93247          10
# 17440    0.525426  0.999509  0.999976  390.0       93250           7
# 17441    0.505942  0.999902  0.999976  383.0       93254           3
# 17442    0.495139  0.999902  1.000000  380.0       93256           1
# 17443    0.494817  1.000000  1.000000  379.0       93257           0
#
#        Approval Rate  Rejection Rate
# 17439       0.999893        0.000107
# 17440       0.999925        0.000075
# 17441       0.999968        0.000032
# 17442       0.999989        0.000011
# 17443       1.000000        0.000000

# %%
inputs_train_with_ref_cat.to_csv('inputs_train_with_ref_cat.csv')

# %%
df_scorecard.to_csv('df_scorecard.csv')
